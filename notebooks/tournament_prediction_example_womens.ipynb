# %%
import wcpredictor

# %%
results = wcpredictor.get_results_data(womens=True)[0]
results
# Out:
# Using results data from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/results_womens.csv
# Using competitions index file from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/results_womens.csv
# Filtering games for period: 2018-06-01 to 2022-11-20
# Using FIFA organisation rankings
# Loading FIFA organisation ratings from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/fifa_rankings_womens.csv
# Only using competitons from ['W', 'C1', 'WQ', 'CQ', 'C2', 'F']
#            date    home_team            away_team  home_score  away_score  \
# 0    2018-06-06      Algeria             Ethiopia           3           1
# 1    2018-06-06       Gambia              Nigeria           0           1
# 2    2018-06-06        Congo             Cameroon           0           5
# 3    2018-06-06        Kenya    Equatorial Guinea           2           1
# 4    2018-06-06      Lesotho         South Africa           0           1
# ...         ...          ...                  ...         ...         ...
# 1089 2022-10-09       Latvia            Lithuania           1           2
# 1090 2022-10-09      Estonia        Faroe Islands           3           1
# 1091 2022-10-11     Portugal              Iceland           4           1
# 1092 2022-10-11     Scotland  Republic of Ireland           0           1
# 1093 2022-10-11  Switzerland                Wales           2           1
#
#                               tournament               city      country  \
# 0     African Championship qualification            Algiers      Algeria
# 1     African Championship qualification              Bakau       Gambia
# 2     African Championship qualification        Brazzaville        Congo
# 3     African Championship qualification           Machakos        Kenya
# 4     African Championship qualification             Maseru      Lesotho
# ...                                  ...                ...          ...
# 1089                          Baltic Cup               Võru      Estonia
# 1090                          Baltic Cup              Tartu      Estonia
# 1091        FIFA World Cup qualification  Paços de Ferreira     Portugal
# 1092        FIFA World Cup qualification            Glasgow     Scotland
# 1093        FIFA World Cup qualification             Zürich  Switzerland
#
#       neutral  time_diff  game_weight
# 0       False   4.460274          1.0
# 1       False   4.460274          1.0
# 2       False   4.460274          1.0
# 3       False   4.460274          1.0
# 4       False   4.460274          1.0
# ...       ...        ...          ...
# 1089     True   0.115068          1.0
# 1090    False   0.115068          1.0
# 1091    False   0.109589          1.0
# 1092    False   0.109589          1.0
# 1093    False   0.109589          1.0
#
# [1094 rows x 11 columns]

# %%
wcpredictor.get_teams_data(year="2023", womens=True)
# Out:
# Loading teams data from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/teams_2023_womens.csv
#                    Team Group
# 0           New Zealand     A
# 1                Norway     A
# 2           Philippines     A
# 3           Switzerland     A
# 4             Australia     B
# 5                Canada     B
# 6               Nigeria     B
# 7   Republic of Ireland     B
# 8            Costa Rica     C
# 9                 Japan     C
# 10                Spain     C
# 11               Zambia     C
# 12             China PR     D
# 13              Denmark     D
# 14              England     D
# 15                Haiti     D
# 16          Netherlands     E
# 17             Portugal     E
# 18                  USA     E
# 19              Vietnam     E
# 20               Brazil     F
# 21               France     F
# 22              Jamaica     F
# 23               Panama     F
# 24            Argentina     G
# 25                Italy     G
# 26         South Africa     G
# 27               Sweden     G
# 28             Colombia     H
# 29              Germany     H
# 30          South Korea     H
# 31              Morocco     H

# %%
wcpredictor.get_fixture_data(year="2023", womens=True)
# Out:
# Loading fixtures data from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/fixtures_2023_womens.csv
#            home_team            away_team       date  stage
# 0        New Zealand               Norway 2023-07-20  Group
# 1          Australia  Republic of Ireland 2023-07-20  Group
# 2            Nigeria               Canada 2023-07-21  Group
# 3        Philippines          Switzerland 2023-07-21  Group
# 4              Spain           Costa Rica 2023-07-21  Group
# ..               ...                  ...        ...    ...
# 58              1B2D                 1F2H 2023-08-12     QF
# 59              1D2B                 1H2F 2023-08-12     QF
# 60          1A2C1E2G             1C2A1G2E 2023-08-15     SF
# 61          1B2D1F2H             1D2B1H2F 2023-08-16     SF
# 62  1A2C1E2G1C2A1G2E     1B2D1F2H1D2B1H2F 2023-08-20      F
#
# [63 rows x 4 columns]

# %%
wcpredictor.get_fifa_rankings_data(source="both", womens=True)
# Out:
# Using FIFA videogame rankings
# Loading FIFA game rankings from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/fifa_game_rankings_womens.csv
# Loading confederations data from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/confederations.csv
# Using FIFA organisation rankings
# Loading FIFA organisation ratings from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/fifa_rankings_womens.csv
#               Team  Attack  Midfield  Defence  Overall   Rating
# 0              USA      87        86       83       85  2090.03
# 1          Germany      82        85       81       83  2061.56
# 2           France      88        78       82       82  2026.65
# 3      Netherlands      83        83       79       81  1980.47
# 4          England      82        79       82       80  2040.76
# ..             ...     ...       ...      ...      ...      ...
# 178         Kosovo      65        65       65       65  1188.46
# 179          Wales      65        65       65       65  1665.82
# 180         Serbia      65        65       65       65  1622.42
# 181        Finland      65        65       65       65  1676.76
# 182  Faroe Islands      65        65       65       65  1201.10
#
# [183 rows x 6 columns]

# %%
wc_pred = wcpredictor.WCPred(results = results)
wc_pred.fit_model()
# Out:
# Loading confederations data from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/confederations.csv
# [MODEL FITTING] Setting training data for the model
# [MODEL FITTING] Fitting the model
# sample: 100%|██████████| 1500/1500 [00:18<00:00, 82.73it/s, 63 steps of size 9.09e-02. acc. prob=0.87]

# %%
wc_pred

# %% [markdown]
# Note that we can fit the model by doing `wc_pred.set_training_data()` and `wc_pred.fit_model()`. These will put training data in `wc_pred.training_data` and the model in `wc_pred.model`.
#
# Now, initialise the tournament:

# %%
tourn = wcpredictor.Tournament(year="2023", womens=True, num_samples=1000)
# Out:
# Loading teams data from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/teams_2023_womens.csv
# Loading fixtures data from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/fixtures_2023_womens.csv
# Resuming tournament simulation from 2023-01-01 00:00:00 at Group stage
# Using results data from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/results_womens.csv
# Using competitions index file from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/results_womens.csv
# Filtering games for period: 2023-01-01 to 2022-12-31 00:00:00
# Using FIFA organisation rankings
# Loading FIFA organisation ratings from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/fifa_rankings_womens.csv
# Only using competitons from W
# Loading in alias data from /Users/rchan/Library/CloudStorage/OneDrive-TheAlanTuringInstitute/WorldCupPrediction/wcpredictor/src/../data/aliases_2023_womens.csv

# %% [markdown]
# Running these last two cells will keep on giving you different answers (the prediction of the games using the model will predict different scorelines and different outcomes from each of the group and knockout games).
#
# It will make predictions based on the model fitted in `wc_pred`.

# %%
tourn.play_group_stage(wc_pred)
# Out:
# Simulating Group...
# Group took 1.04s

# %%
tourn.play_knockout_stages(wc_pred)
# Out:
# Simulating R16
# R16 took 50.09s
# Simulating QF
# QF took 13.75s
# Simulating SF
# SF took 4.12s
# Simulating F
# F took 2.29s

# %%
tourn.winner
# Out:
# array(['France', 'USA', 'USA', 'Germany', 'USA', 'Spain', 'Sweden',
#        'Spain', 'England', 'USA', 'Spain', 'England', 'Spain', 'USA',
#        'England', 'USA', 'USA', 'Germany', 'England', 'USA', 'USA', 'USA',
#        'Germany', 'France', 'England', 'England', 'USA', 'England',
#        'England', 'England', 'USA', 'USA', 'USA', 'England', 'England',
#        'France', 'USA', 'Spain', 'Germany', 'Spain', 'Germany', 'USA',
#        'USA', 'France', 'England', 'USA', 'USA', 'USA', 'England',
#        'Germany', 'USA', 'England', 'Germany', 'USA', 'France', 'USA',
#        'France', 'France', 'USA', 'Germany', 'USA', 'USA', 'USA',
#        'Sweden', 'USA', 'Germany', 'England', 'Spain', 'England',
#        'Germany', 'France', 'USA', 'USA', 'USA', 'USA', 'England', 'USA',
#        'USA', 'England', 'England', 'England', 'USA', 'USA', 'USA', 'USA',
#        'USA', 'USA', 'England', 'France', 'USA', 'Spain', 'Germany',
#        'England', 'USA', 'England', 'Spain', 'USA', 'USA', 'England',
#        'Germany', 'England', 'USA', 'USA', 'Germany', 'England',
#        'Netherlands', 'USA'], dtype='<U22')

# %% [markdown]
# # Replaying tournaments

# %%
tourn.count_stages()
tourn.stage_counts
# Out:
#                      Group  R16   QF   SF   RU    W
# Team
# New Zealand            808  184    8    0    0    0
# Norway                  42  444  384   96   25    9
# Philippines            966   32    2    0    0    0
# Switzerland            184  607  173   28    8    0
# Australia              219  445  202   98   23   13
# Canada                 303  443  172   69   12    1
# Nigeria                859  119   20    2    0    0
# Republic of Ireland    619  310   56   11    4    0
# Costa Rica             857  122   19    2    0    0
# Japan                  149  418  338   70   19    6
# Spain                   16  172  318  298  101   95
# Zambia                 978   21    1    0    0    0
# China PR               547  247  148   47    9    2
# Denmark                429  278  202   74   14    3
# England                 64  121  273  137  190  215
# Haiti                  960   37    3    0    0    0
# Netherlands            154  395  226  170   39   16
# Portugal               855  112   33    0    0    0
# USA                     11  138  120  143  180  408
# Vietnam                980   16    3    1    0    0
# Brazil                  62  570  234  105   24    5
# France                   4  239  248  284  141   84
# Jamaica                943   55    2    0    0    0
# Panama                 991    9    0    0    0    0
# Argentina              901   98    1    0    0    0
# Italy                  159  637  128   61   13    2
# South Africa           880  115    5    0    0    0
# Sweden                  60  489  241  131   54   25
# Colombia               613  340   39    6    2    0
# Germany                 18  266  321  139  140  116
# South Korea            408  485   77   28    2    0
# Morocco                961   36    3    0    0    0

# %%
from matplotlib import pyplot as plt
def plot_winner_bar_plot(df, top=10, title = None):
    by_W_order = df.sort_values(by="W", ascending=False)
    plt.bar(by_W_order.index[:top], by_W_order["W"].iloc[:top])
    plt.xticks(rotation=90)
    if title is not None:
        plt.title(title)
    plt.show()
    
def plot_winner_bar_plot_multiple(df_list, plot_dim, top=10, title_list=None):
    plt.subplots(plot_dim[0], plot_dim[1], figsize=(12,8))
    if title_list is not None:
        if len(df_list)!=len(title_list):
            raise ValueError("length of df_list and title_list should be the same if title_list is passed")
    for i in range(len(df_list)):
        plt.subplot(plot_dim[0], plot_dim[1], i+1)
        by_W_order = df_list[i].sort_values(by="W", ascending=False)
        plt.bar(by_W_order["Team"].iloc[:top], by_W_order["W"].iloc[:top])
        plt.xticks(rotation=90)
        if title_list is not None:
            plt.title(title_list[i])

# %%
plot_winner_bar_plot(tourn.stage_counts, 15)
